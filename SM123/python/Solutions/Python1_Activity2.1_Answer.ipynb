# %% [markdown]
# # A possible answer to Activity 2.1 in Python 1

# %%
items = [1.45, 2, 0.25, 4.4, 1.9]  # masses in kg  

tot_number_items = len(items) 

print ("Number of elements in items:", tot_number_items)

# %% [markdown]
# # Radioactive decay program
# &nbsp;
#
# In the activity below, you will write a program that performs calculations related to radioactive decay. This is the program that you will share with another student in the next activity.
#
# The activity also requires that the program plots the amount of an isotope that is left, $P$, as a function of elapsed time, $t$. You should use Equation 2.1b in Topic 6:
#
# $P = P_0 \left( \frac{1}{2} \right)^n = P_0 \left( \frac{1}{2}\right)^{\frac{t}{\tau}}$
#
# where $\tau$ is the half life, so $\frac{t}{\tau}$ is the number of half-lives elapsed, $n$.

# %% [markdown]
# ### Python activity 3.1 Write a program using Python
#
# *Allow approximately 2 hours*
#
# Write a program using Python that does the following:
# 1. Prompts the user to input the name of a particular isotope and its half-life, $\tau$, in seconds.
# 2. Prompts the user for an initial amount of the isotope (in grams) and an elapsed time (in seconds).
# 3. Calculates the amount of the isotope remaining after this elapsed time and displays the result.
# 4. Calculates the initial mass of the isotope (in grams) necessary to ensure that, after half a minute, 5 grams of it remain, and displays the result.
# 5. Plots the amount of the isotope remaining as a function of time, from elapsed time $t = 0$ s until $t = 10$ s.
# 6. The program should then repeat the instructions from step 1, until the user chooses to halt the program.
# 7. When the user wishes to enter no more isotopes, the program should display the decay plots for all of the isotopes that were entered, in a single plot, and print out a list of all the isotopes studied.
#
# The user may like to use isotopes selected from the list below. (The number next to the name of the atom indicates the number of nucleons in the isotope).
#
# *Hints*:
# * You will probably want to import functions from the `numpy`, `math` and `matplotlib` packages.
# * You will probably want to make use of Equations 2.1a and 2.1c from Topic 6, Section 2.5. You may also want to revise the exercises that appear after those equations.
#
# Make sure you test the code to confirm it provides correct results.
#
# No model solution to this Activity is provided, as it forms part of an assessed task in TMA 04.

# %%
# Write your python code here.

# %% [markdown]
# <u>Table of isotope half-lives (Wikipedia, 2018)</u>
#
# | Isotope | Half-life in seconds|
# |----------|---------|
# |oxygen-22|	2.25 |
# |carbon-15|	2.45 |
# |flerovium-289|	2.6 |
# |oxygen-21|	3.42 |
# |nitrogen-17|	4.17 |
# |beryllium-14|	4.84 |
# |nitrogen-16|	7.13 |
# |oxygen-20|	13.5 |
# |beryllium-11|	13.8 |
# |carbon-10|	19.3 |
# |oxygen-19|	26.5 |
# |dubnium-261|	27 |
# |seaborgium-266|	30 |
# |dubnium-262|	34 |

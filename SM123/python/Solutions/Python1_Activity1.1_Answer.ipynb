# %% [markdown]
# # A possible answer to Activity 1.1 in Python 1

# %%
result = 3 - 7
print ("The difference between  3 and 7 is", result)
result= 3*7
print ("The product of 3 and 7 is", result)
result=3/7
print ("The ratio between  3 and 7 is", result)
result= 3**7
print ("3 to the power of 7 is", result)
